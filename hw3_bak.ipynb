# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from hw3.hw3 import *

# %% [markdown]
# ## Problem 1 (a):

# %%
problem_1_part_a()
# Out:
# Test MRSE: 3.13

# %% [markdown]
# ## Problem 1 (b):

# %%
problem_1_part_b()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>s^2=0.1</th>
#       <th>s^2=0.2</th>
#       <th>s^2=0.3</th>
#       <th>s^2=0.4</th>
#       <th>s^2=0.5</th>
#       <th>s^2=0.6</th>
#       <th>s^2=0.7</th>
#       <th>s^2=0.8</th>
#       <th>s^2=0.9</th>
#       <th>s^2=1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>b=5</th>
#       <td>1.968375</td>
#       <td>1.935695</td>
#       <td>1.926298</td>
#       <td>1.925341</td>
#       <td>1.928144</td>
#       <td>1.932793</td>
#       <td>1.938400</td>
#       <td>1.944518</td>
#       <td>1.950910</td>
#       <td>1.957447</td>
#     </tr>
#     <tr>
#       <th>b=7</th>
#       <td>1.921775</td>
#       <td>1.906854</td>
#       <td>1.910319</td>
#       <td>1.918335</td>
#       <td>1.927385</td>
#       <td>1.936397</td>
#       <td>1.945039</td>
#       <td>1.953237</td>
#       <td>1.961007</td>
#       <td>1.968399</td>
#     </tr>
#     <tr>
#       <th>b=9</th>
#       <td>1.898987</td>
#       <td>1.904196</td>
#       <td>1.919520</td>
#       <td>1.934500</td>
#       <td>1.947749</td>
#       <td>1.959318</td>
#       <td>1.969499</td>
#       <td>1.978587</td>
#       <td>1.986826</td>
#       <td>1.994411</td>
#     </tr>
#     <tr>
#       <th>b=11</th>
#       <td>1.891693</td>
#       <td>1.916448</td>
#       <td>1.940431</td>
#       <td>1.959555</td>
#       <td>1.974831</td>
#       <td>1.987353</td>
#       <td>1.997925</td>
#       <td>2.007108</td>
#       <td>2.015292</td>
#       <td>2.022752</td>
#     </tr>
#     <tr>
#       <th>b=13</th>
#       <td>1.896930</td>
#       <td>1.936870</td>
#       <td>1.965923</td>
#       <td>1.986806</td>
#       <td>2.002568</td>
#       <td>2.015070</td>
#       <td>2.025434</td>
#       <td>2.034362</td>
#       <td>2.042306</td>
#       <td>2.049567</td>
#     </tr>
#     <tr>
#       <th>b=15</th>
#       <td>1.910596</td>
#       <td>1.960666</td>
#       <td>1.991906</td>
#       <td>2.012957</td>
#       <td>2.028334</td>
#       <td>2.040346</td>
#       <td>2.050263</td>
#       <td>2.058827</td>
#       <td>2.066495</td>
#       <td>2.073558</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Problem 2 (c):

# %% [markdown]
# Best test MRSE value for GP is **1.891** for hyper-parameters b=11 and sigma^2=0.1. From HW1, the best MRSE for Least Squares regression was **2.634**, and best MRSE for Ridge Regressions (polynomial order 2 feature expansion) was **2.193**. On the test set GP clearly outperforms both LS and RR models.
#
# The drawback in GP is the computational complexity. In both LS and RR linear models the computational complexity of matrix multiplication is $O(ND^2)$ and for matrix inverse $O(D^3)$. Since D << N, the overall complexity will be $(ND^2)$. For Gaussian Process the matrix inversion is computed on the covariance matrix NxN and its complexity $O(D^3)$ will dominate other computations.

# %% [markdown]
# ## Problem 2 (d):

# %%
problem_1_part_d()

# %%
results = train_boosted_classifier(1500)

# %%
problem_2_part_a(*results)

# %%
problem_2_part_b(*results)

# %%
problem_2_part_c(*results)

# %%
problem_2_part_d(*results)

# %% [markdown]
# ## References:
#
# * https://en.wikipedia.org/wiki/Computational_complexity_of_mathematical_operations
